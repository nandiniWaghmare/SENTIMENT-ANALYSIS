# %%
# !pip install textblob
# Out:
# Requirement already satisfied: textblob in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (0.20.0)
# Requirement already satisfied: nltk>=3.9 in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (from textblob) (3.9.4)
# Requirement already satisfied: click in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (from nltk>=3.9->textblob) (8.3.3)
# Requirement already satisfied: joblib in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (from nltk>=3.9->textblob) (1.5.3)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (from nltk>=3.9->textblob) (2026.4.4)
# Requirement already satisfied: tqdm in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (from nltk>=3.9->textblob) (4.67.3)
# Requirement already satisfied: colorama in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (from click->nltk>=3.9->textblob) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install --upgrade pip
# Out:
# Requirement already satisfied: pip in c:\users\pooja pc\appdata\local\programs\python\python314\lib\site-packages (25.3)
# Collecting pip
#   Downloading pip-26.1.1-py3-none-any.whl.metadata (4.6 kB)
# Downloading pip-26.1.1-py3-none-any.whl (1.8 MB)
#    ---------------------------------------- 0.0/1.8 MB ? eta -:--:--
#    ---------------------------------------- 1.8/1.8 MB 12.5 MB/s  0:00:00
# Installing collected packages: pip
#   Attempting uninstall: pip
#     Found existing installation: pip 25.3
#     Uninstalling pip-25.3:
#       Successfully uninstalled pip-25.3
# Successfully installed pip-26.1.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from textblob import TextBlob
import matplotlib.pyplot as plt

# %%
data = {
    "review": [
        "This product is amazing!",
        "Worst experience ever",
        "It is okay, not great",
        "Absolutely fantastic service",
        "I hate this item",
        "Very good quality",
        "Not bad, could be better"
    ]
}

df = pd.DataFrame(data)
df.head()
# Out:
#                          review
# 0      This product is amazing!
# 1         Worst experience ever
# 2         It is okay, not great
# 3  Absolutely fantastic service
# 4              I hate this item

# %%
def get_sentiment(text):
    analysis = TextBlob(text)
    
    if analysis.sentiment.polarity > 0:
        return "Positive"
    elif analysis.sentiment.polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df['sentiment'] = df['review'].apply(get_sentiment)

df
# Out:
#                          review sentiment
# 0      This product is amazing!  Positive
# 1         Worst experience ever  Negative
# 2         It is okay, not great  Positive
# 3  Absolutely fantastic service  Positive
# 4              I hate this item  Negative
# 5             Very good quality  Positive
# 6      Not bad, could be better  Positive

# %%
sentiment_count = df['sentiment'].value_counts()
print(sentiment_count)
# Out:
# sentiment
# Positive    5
# Negative    2
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

sentiment_count.plot(kind='bar')
plt.title("Sentiment Analysis Result")
plt.xlabel("Sentiment")
plt.ylabel("Count")
plt.show()
